# %% [markdown]
# ## Automated Car in Project Cars

# %% [markdown]
# Work based on the project madeby Sentdex in his blog: https://pythonprogramming.net/game-frames-open-cv-python-plays-gta-v/

# %%
import numpy as np
from numpy import ones,vstack
from numpy.linalg import lstsq
from PIL import ImageGrab
import cv2
import time
from IPython.display import Image
import ctypes
from statistics import mean

def screen_record(): 
    last_time = time.time()
    while(True):
        # 800x600 windowed mode
        printscreen =  np.array(ImageGrab.grab(bbox=(0,40,800,640)))
        print('loop took {} seconds'.format(time.time()-last_time))
        last_time = time.time()
        cv2.imshow('window',cv2.cvtColor(printscreen, cv2.COLOR_BGR2RGB))
        if cv2.waitKey(25) & 0xFF == ord('q'):
            cv2.destroyAllWindows()
            break

# %% [markdown]
# array: [10,500],[10,300],[300,300],[500,300],[800,300],[800,500]

# %%
def process_img(image):
    original_image = image
    # convert to gray
    processed_img = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    # edge detection
    processed_img =  cv2.Canny(processed_img, threshold1 = 200, threshold2=300)
    
    processed_img = cv2.GaussianBlur(processed_img,(5,5),0)
    
    vertices = np.array([[10,500],[10,300],[300,200],[500,200],[800,300],[800,500],
                         ], np.int32)

    processed_img = roi(processed_img, [vertices])

    # more info: http://docs.opencv.org/3.0-beta/doc/py_tutorials/py_imgproc/py_houghlines/py_houghlines.html
    #                                     rho   theta   thresh  min length, max gap:        
    lines = cv2.HoughLinesP(processed_img, 1, np.pi/180, 180,      20,       15)
    m1 = 0
    m2 = 0
    try:
        l1, l2, m1,m2 = draw_lanes(original_image,lines)
        cv2.line(original_image, (l1[0], l1[1]), (l1[2], l1[3]), [0,255,0], 30)
        cv2.line(original_image, (l2[0], l2[1]), (l2[2], l2[3]), [0,255,0], 30)
    except Exception as e:
        print(str(e))
        pass
    try:
        for coords in lines:
            coords = coords[0]
            try:
                cv2.line(processed_img, (coords[0], coords[1]), (coords[2], coords[3]), [255,0,0], 3)
                
                
            except Exception as e:
                print(str(e))
    except Exception as e:
        pass

    return processed_img,original_image, m1, m2

# %%
def draw_lines(img, lines):
    try:
        for line in lines:
            coords = line[0]
            cv2.line(img, (coords[0],coords[1]), (coords[2],coords[3]), [255,255,255], 3)
    except:
        pass

# %%
def roi(img, vertices):
    
    #blank mask:
    mask = np.zeros_like(img)   
    
    #filling pixels inside the polygon defined by "vertices" with the fill color    
    cv2.fillPoly(mask, vertices, 255)
    
    #returning the image only where mask pixels are nonzero
    masked = cv2.bitwise_and(img, mask)
    return masked

# %%
def draw_lanes(img, lines, color=[0, 255, 255], thickness=3):

    # if this fails, go with some default line
    try:

        # finds the maximum y value for a lane marker 
        # (since we cannot assume the horizon will always be at the same point.)

        ys = []  
        for i in lines:
            for ii in i:
                ys += [ii[1],ii[3]]
        min_y = min(ys)
        max_y = 600
        new_lines = []
        line_dict = {}

        for idx,i in enumerate(lines):
            for xyxy in i:
                # These four lines:
                # modified from http://stackoverflow.com/questions/21565994/method-to-return-the-equation-of-a-straight-line-given-two-points
                # Used to calculate the definition of a line, given two sets of coords.
                x_coords = (xyxy[0],xyxy[2])
                y_coords = (xyxy[1],xyxy[3])
                A = vstack([x_coords,ones(len(x_coords))]).T
                m, b = lstsq(A, y_coords)[0]

                # Calculating our new, and improved, xs
                x1 = (min_y-b) / m
                x2 = (max_y-b) / m

                line_dict[idx] = [m,b,[int(x1), min_y, int(x2), max_y]]
                new_lines.append([int(x1), min_y, int(x2), max_y])

        final_lanes = {}

        for idx in line_dict:
            final_lanes_copy = final_lanes.copy()
            m = line_dict[idx][0]
            b = line_dict[idx][1]
            line = line_dict[idx][2]
            
            if len(final_lanes) == 0:
                final_lanes[m] = [ [m,b,line] ]
                
            else:
                found_copy = False

                for other_ms in final_lanes_copy:

                    if not found_copy:
                        if abs(other_ms*1.2) > abs(m) > abs(other_ms*0.8):
                            if abs(final_lanes_copy[other_ms][0][1]*1.2) > abs(b) > abs(final_lanes_copy[other_ms][0][1]*0.8):
                                final_lanes[other_ms].append([m,b,line])
                                found_copy = True
                                break
                        else:
                            final_lanes[m] = [ [m,b,line] ]

        line_counter = {}

        for lanes in final_lanes:
            line_counter[lanes] = len(final_lanes[lanes])

        top_lanes = sorted(line_counter.items(), key=lambda item: item[1])[::-1][:2]

        lane1_id = top_lanes[0][0]
        lane2_id = top_lanes[1][0]

        def average_lane(lane_data):
            x1s = []
            y1s = []
            x2s = []
            y2s = []
            for data in lane_data:
                x1s.append(data[2][0])
                y1s.append(data[2][1])
                x2s.append(data[2][2])
                y2s.append(data[2][3])
            return int(mean(x1s)), int(mean(y1s)), int(mean(x2s)), int(mean(y2s)) 

        l1_x1, l1_y1, l1_x2, l1_y2 = average_lane(final_lanes[lane1_id])
        l2_x1, l2_y1, l2_x2, l2_y2 = average_lane(final_lanes[lane2_id])

        return [l1_x1, l1_y1, l1_x2, l1_y2], [l2_x1, l2_y1, l2_x2, l2_y2], lane1_id, lane2_id
    except Exception as e:
        print(str(e))

# %%
# direct inputs
# source to this solution and code:
# http://stackoverflow.com/questions/14489013/simulate-python-keypresses-for-controlling-a-game
# http://www.gamespp.com/directx/directInputKeyboardScanCodes.html

SendInput = ctypes.windll.user32.SendInput


W = 0x11
A = 0x1E
S = 0x1F
D = 0x20

# C struct redefinitions 
PUL = ctypes.POINTER(ctypes.c_ulong)
class KeyBdInput(ctypes.Structure):
    _fields_ = [("wVk", ctypes.c_ushort),
                ("wScan", ctypes.c_ushort),
                ("dwFlags", ctypes.c_ulong),
                ("time", ctypes.c_ulong),
                ("dwExtraInfo", PUL)]

class HardwareInput(ctypes.Structure):
    _fields_ = [("uMsg", ctypes.c_ulong),
                ("wParamL", ctypes.c_short),
                ("wParamH", ctypes.c_ushort)]

class MouseInput(ctypes.Structure):
    _fields_ = [("dx", ctypes.c_long),
                ("dy", ctypes.c_long),
                ("mouseData", ctypes.c_ulong),
                ("dwFlags", ctypes.c_ulong),
                ("time",ctypes.c_ulong),
                ("dwExtraInfo", PUL)]

class Input_I(ctypes.Union):
    _fields_ = [("ki", KeyBdInput),
                 ("mi", MouseInput),
                 ("hi", HardwareInput)]

class Input(ctypes.Structure):
    _fields_ = [("type", ctypes.c_ulong),
                ("ii", Input_I)]

# Actuals Functions

def PressKey(hexKeyCode):
    extra = ctypes.c_ulong(0)
    ii_ = Input_I()
    ii_.ki = KeyBdInput( 0, hexKeyCode, 0x0008, 0, ctypes.pointer(extra) )
    x = Input( ctypes.c_ulong(1), ii_ )
    ctypes.windll.user32.SendInput(1, ctypes.pointer(x), ctypes.sizeof(x))

def ReleaseKey(hexKeyCode):
    extra = ctypes.c_ulong(0)
    ii_ = Input_I()
    ii_.ki = KeyBdInput( 0, hexKeyCode, 0x0008 | 0x0002, 0, ctypes.pointer(extra) )
    x = Input( ctypes.c_ulong(1), ii_ )
    ctypes.windll.user32.SendInput(1, ctypes.pointer(x), ctypes.sizeof(x))

if __name__ == '__main__':
    PressKey(0x11)
    time.sleep(1)
    ReleaseKey(0x11)
    time.sleep(1)

# %%
def straight():
    PressKey(W)
    ReleaseKey(A)
    ReleaseKey(D)

def left():
    PressKey(A)
    ReleaseKey(W)
    ReleaseKey(D)
    ReleaseKey(A)

def right():
    PressKey(D)
    ReleaseKey(A)
    ReleaseKey(W)
    ReleaseKey(D)

def slow_ya_roll():
    ReleaseKey(W)
    ReleaseKey(A)
    ReleaseKey(D)

# %%
def main():
    last_time = time.time()
    while True:
        screen =  np.array(ImageGrab.grab(bbox=(0,40,800,640)))
        print('Frame took {} seconds'.format(time.time()-last_time))
        last_time = time.time()
        new_screen,original_image, m1, m2 = process_img(screen)
        #cv2.imshow('window', new_screen)
        cv2.imshow('window2',cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB))

        if m1 < 0 and m2 < 0:
            right()
        elif m1 > 0  and m2 > 0:
            left()
        else:
            straight()

        #cv2.imshow('window',cv2.cvtColor(screen, cv2.COLOR_BGR2RGB))
        if cv2.waitKey(25) & 0xFF == ord('q'):
            cv2.destroyAllWindows()
            break

# %%
main()
# Out:
# Frame took 0.03702235221862793 seconds
# Frame took 0.09702205657958984 seconds
# Frame took 0.06500792503356934 seconds
# <ipython-input-58-276e653d8b1c>:26: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   m, b = lstsq(A, y_coords)[0]
# Frame took 0.06600785255432129 seconds
# Frame took 0.06902241706848145 seconds
# Frame took 0.06800651550292969 seconds
# Frame took 0.06102895736694336 seconds
# Frame took 0.06801557540893555 seconds
# Frame took 0.07000207901000977 seconds
# Frame took 0.08402585983276367 seconds
# Frame took 0.09801506996154785 seconds
# Frame took 0.10002899169921875 seconds
# Frame took 0.0980224609375 seconds
# Frame took 0.08201169967651367 seconds
# Frame took 0.08603310585021973 seconds
# Frame took 0.09801530838012695 seconds
# Frame took 0.08402538299560547 seconds
# Frame took 0.08101820945739746 seconds
# Frame took 0.09900832176208496 seconds
# Frame took 0.09902143478393555 seconds
# Frame took 0.10502338409423828 seconds
# Frame took 0.0980374813079834 seconds
# Frame took 0.10101675987243652 seconds
# Frame took 0.09702038764953613 seconds
# Frame took 0.08501911163330078 seconds
# Frame took 0.08501935005187988 seconds
# Frame took 0.09802842140197754 seconds
# Frame took 0.10301661491394043 seconds
# Frame took 0.09702134132385254 seconds
# Frame took 0.0980219841003418 seconds
# Frame took 0.10302948951721191 seconds
# Frame took 0.08001828193664551 seconds
# Frame took 0.08501267433166504 seconds
# Frame took 0.10202264785766602 seconds
# Frame took 0.08202457427978516 seconds
# Frame took 0.10102272033691406 seconds
# Frame took 0.10001587867736816 seconds
# Frame took 0.09902238845825195 seconds
# Frame took 0.10002923011779785 seconds
# Frame took 0.0980067253112793 seconds
# Frame took 0.10103130340576172 seconds
# Frame took 0.10402321815490723 seconds
# Frame took 0.09701323509216309 seconds
# Frame took 0.10203146934509277 seconds
# Frame took 0.09802842140197754 seconds
# Frame took 0.08101820945739746 seconds
# Frame took 0.10202264785766602 seconds
# Frame took 0.11504173278808594 seconds
# Frame took 0.0820155143737793 seconds
# Frame took 0.08501267433166504 seconds
# Frame took 0.0990145206451416 seconds
# Frame took 0.10102987289428711 seconds
# Frame took 0.08402562141418457 seconds
# Frame took 0.1000223159790039 seconds
# Frame took 0.10102272033691406 seconds
# Frame took 0.09901571273803711 seconds
# Frame took 0.08201050758361816 seconds
# Frame took 0.10203146934509277 seconds
# Frame took 0.0990147590637207 seconds
# Frame took 0.1010293960571289 seconds
# Frame took 0.09702825546264648 seconds
# Frame took 0.09801602363586426 seconds
# Frame took 0.08701300621032715 seconds
# Frame took 0.08303093910217285 seconds
# Frame took 0.10001587867736816 seconds
# Frame took 0.1010289192199707 seconds
# Frame took 0.08100485801696777 seconds
# Frame took 0.08402585983276367 seconds
# Frame took 0.10202932357788086 seconds
# Frame took 0.08400392532348633 seconds
# Frame took 0.08002161979675293 seconds
# Frame took 0.10001969337463379 seconds
# Frame took 0.09603452682495117 seconds
# Frame took 0.08801937103271484 seconds
# Frame took 0.09902238845825195 seconds
# Frame took 0.10001587867736816 seconds
# Frame took 0.08501935005187988 seconds
# Frame took 0.10002851486206055 seconds
# Frame took 0.09901595115661621 seconds
# Frame took 0.0980067253112793 seconds
# Frame took 0.09801340103149414 seconds
# Frame took 0.08302593231201172 seconds
# Frame took 0.09702825546264648 seconds
# Frame took 0.0860135555267334 seconds
# Frame took 0.08701896667480469 seconds
# Frame took 0.09802842140197754 seconds
# Frame took 0.08201122283935547 seconds
# Frame took 0.08503246307373047 seconds
# Frame took 0.0990152359008789 seconds
# Frame took 0.09902215003967285 seconds
# Frame took 0.08602571487426758 seconds
# Frame took 0.07901144027709961 seconds
# Frame took 0.08601140975952148 seconds
# Frame took 0.0990302562713623 seconds
# Frame took 0.08101797103881836 seconds
# Frame took 0.08502030372619629 seconds
# Frame took 0.1010286808013916 seconds
# Frame took 0.08201122283935547 seconds
# Frame took 0.08402514457702637 seconds
# Frame took 0.10101580619812012 seconds
# Frame took 0.0790247917175293 seconds
# Frame took 0.08802628517150879 seconds
# Frame took 0.10001635551452637 seconds
# Frame took 0.09602069854736328 seconds
# Frame took 0.08502602577209473 seconds
# Frame took 0.0800178050994873 seconds
# Frame took 0.08501267433166504 seconds
# Frame took 0.10302925109863281 seconds
# Frame took 0.08101201057434082 seconds
# Frame took 0.08201789855957031 seconds
# Frame took 0.0870199203491211 seconds
# Frame took 0.0980224609375 seconds
# Frame took 0.08402824401855469 seconds
# Frame took 0.08401894569396973 seconds
# Frame took 0.0800178050994873 seconds
# Frame took 0.08501124382019043 seconds
# Frame took 0.0890343189239502 seconds
# Frame took 0.07500457763671875 seconds
# Frame took 0.08502459526062012 seconds
# Frame took 0.08401107788085938 seconds
# Frame took 0.08301806449890137 seconds
# Frame took 0.08201813697814941 seconds
# Frame took 0.08502054214477539 seconds
# Frame took 0.08202552795410156 seconds
# Frame took 0.08302521705627441 seconds
# Frame took 0.08501315116882324 seconds
# Python int too large to convert to C long
# Frame took 0.08001708984375 seconds
# Frame took 0.06501460075378418 seconds
# Frame took 0.07101798057556152 seconds
# Frame took 0.08302497863769531 seconds
# Python int too large to convert to C long
# Frame took 0.08101677894592285 seconds
# Python int too large to convert to C long
# Frame took 0.08600568771362305 seconds
# Python int too large to convert to C long
# Frame took 0.08402562141418457 seconds
# list index out of range
# cannot unpack non-iterable NoneType object
# Frame took 0.08201837539672852 seconds
# Frame took 0.08402538299560547 seconds
# Frame took 0.08401250839233398 seconds
# Frame took 0.0810244083404541 seconds
# Frame took 0.08501386642456055 seconds
# Frame took 0.08301138877868652 seconds
# Frame took 0.09702801704406738 seconds
# Frame took 0.08601903915405273 seconds
# Frame took 0.08301877975463867 seconds
# Frame took 0.08201789855957031 seconds
# Frame took 0.10302424430847168 seconds
# Frame took 0.09902811050415039 seconds
# Frame took 0.09701824188232422 seconds
# Frame took 0.1010286808013916 seconds
# Frame took 0.08202266693115234 seconds
# Frame took 0.08400940895080566 seconds
# Frame took 0.09903168678283691 seconds
# Frame took 0.09902095794677734 seconds
# Frame took 0.08202481269836426 seconds
# Frame took 0.08701968193054199 seconds
# Frame took 0.09901642799377441 seconds
# Frame took 0.10102224349975586 seconds
# Frame took 0.08402490615844727 seconds
# Frame took 0.0800180435180664 seconds
# Frame took 0.08601951599121094 seconds
# Frame took 0.08500385284423828 seconds
# Frame took 0.08001899719238281 seconds
# Frame took 0.08803391456604004 seconds
# Frame took 0.09602117538452148 seconds
# Frame took 0.08202552795410156 seconds
# Frame took 0.08001089096069336 seconds
# Frame took 0.08701968193054199 seconds
# Frame took 0.08302497863769531 seconds
# Frame took 0.08300423622131348 seconds
# Frame took 0.10203051567077637 seconds
# Frame took 0.10001492500305176 seconds
# Frame took 0.08702731132507324 seconds
# Frame took 0.09702229499816895 seconds
# Python int too large to convert to C long
# Frame took 0.10002827644348145 seconds
# Frame took 0.08201837539672852 seconds
# Frame took 0.08301949501037598 seconds
# Frame took 0.09601449966430664 seconds
# Frame took 0.08802580833435059 seconds
# Frame took 0.08101177215576172 seconds
# Python int too large to convert to C long
# Frame took 0.0820305347442627 seconds
# Python int too large to convert to C long
# Frame took 0.10401344299316406 seconds
# Frame took 0.08100724220275879 seconds
# Python int too large to convert to C long
# Frame took 0.08303380012512207 seconds
# Frame took 0.08401274681091309 seconds
# Frame took 0.08301830291748047 seconds
# Frame took 0.08301019668579102 seconds
# Frame took 0.08203291893005371 seconds
# Frame took 0.08501291275024414 seconds
# Frame took 0.08202528953552246 seconds
# Python int too large to convert to C long
# Frame took 0.08501315116882324 seconds
# Frame took 0.08202219009399414 seconds
# Python int too large to convert to C long
# Frame took 0.08501458168029785 seconds
# Frame took 0.081024169921875 seconds
# Frame took 0.0860137939453125 seconds
# Frame took 0.08202385902404785 seconds
# Python int too large to convert to C long
# Frame took 0.10101628303527832 seconds
# Frame took 0.08301210403442383 seconds
# Python int too large to convert to C long
# Frame took 0.0810246467590332 seconds
# Python int too large to convert to C long
# Frame took 0.08402538299560547 seconds
# Python int too large to convert to C long
# Frame took 0.10201644897460938 seconds
# Python int too large to convert to C long
# Frame took 0.07902383804321289 seconds
# Python int too large to convert to C long
# Frame took 0.08500456809997559 seconds
# Python int too large to convert to C long
# Frame took 0.08703470230102539 seconds
# Python int too large to convert to C long
# Frame took 0.08201169967651367 seconds
# Python int too large to convert to C long
# Frame took 0.08101797103881836 seconds
# Python int too large to convert to C long
# Frame took 0.08701944351196289 seconds
# Python int too large to convert to C long
# Frame took 0.08101868629455566 seconds
# Frame took 0.0990304946899414 seconds
# Python int too large to convert to C long
# Frame took 0.08801150321960449 seconds
# Frame took 0.07702517509460449 seconds
# Frame took 0.08401179313659668 seconds
# Frame took 0.08403301239013672 seconds
# Frame took 0.08201766014099121 seconds
# Frame took 0.08601737022399902 seconds
# Frame took 0.10101795196533203 seconds
# Frame took 0.08001828193664551 seconds
# Frame took 0.08501243591308594 seconds
# Frame took 0.08502578735351562 seconds
# Frame took 0.09601283073425293 seconds
# Frame took 0.10203218460083008 seconds
# Python int too large to convert to C long
# Frame took 0.0800168514251709 seconds
# Frame took 0.08301830291748047 seconds
# Frame took 0.10203027725219727 seconds
# Python int too large to convert to C long
# Frame took 0.0810244083404541 seconds
# Frame took 0.08501291275024414 seconds
# Python int too large to convert to C long
# Frame took 0.08602690696716309 seconds
# Frame took 0.08101344108581543 seconds
# Frame took 0.0830223560333252 seconds
# Frame took 0.08600473403930664 seconds
# Frame took 0.0980367660522461 seconds
# Frame took 0.08301830291748047 seconds
# Frame took 0.08701276779174805 seconds
# Python int too large to convert to C long
# Frame took 0.09302759170532227 seconds
# Python int too large to convert to C long
# Frame took 0.08701372146606445 seconds
# Python int too large to convert to C long
# Frame took 0.08301949501037598 seconds
# Frame took 0.08102297782897949 seconds
# Frame took 0.08501839637756348 seconds
# Frame took 0.08501625061035156 seconds
# Frame took 0.08201265335083008 seconds
# Frame took 0.08302903175354004 seconds
# Frame took 0.08401727676391602 seconds
# Frame took 0.0790243148803711 seconds
# list index out of range
# cannot unpack non-iterable NoneType object
# Frame took 0.07000851631164551 seconds
# 'NoneType' object is not iterable
# cannot unpack non-iterable NoneType object
# Frame took 0.0890207290649414 seconds
# 'NoneType' object is not iterable
# cannot unpack non-iterable NoneType object
# Frame took 0.07602334022521973 seconds
# 'NoneType' object is not iterable
# cannot unpack non-iterable NoneType object
# Frame took 0.08202505111694336 seconds
# 'NoneType' object is not iterable
# cannot unpack non-iterable NoneType object
# Frame took 0.08200478553771973 seconds
# list index out of range
# cannot unpack non-iterable NoneType object
# Frame took 0.07001495361328125 seconds
# list index out of range
# cannot unpack non-iterable NoneType object
# Frame took 0.08102607727050781 seconds
# list index out of range
# cannot unpack non-iterable NoneType object
# Frame took 0.08502554893493652 seconds
# list index out of range
# cannot unpack non-iterable NoneType object
# Frame took 0.08401894569396973 seconds
# Frame took 0.06501436233520508 seconds
# Frame took 0.08501267433166504 seconds
# list index out of range
# cannot unpack non-iterable NoneType object
# Frame took 0.08201861381530762 seconds
# list index out of range
# cannot unpack non-iterable NoneType object
# Frame took 0.08302044868469238 seconds
# Frame took 0.06500458717346191 seconds
# Frame took 0.08102011680603027 seconds
# Frame took 0.08702540397644043 seconds
# list index out of range
# cannot unpack non-iterable NoneType object
# Frame took 0.08001852035522461 seconds
# Frame took 0.07100868225097656 seconds
# Frame took 0.08401703834533691 seconds
# list index out of range
# cannot unpack non-iterable NoneType object
# Frame took 0.08202695846557617 seconds
# 'NoneType' object is not iterable
# cannot unpack non-iterable NoneType object
# Frame took 0.08201909065246582 seconds
# 'NoneType' object is not iterable
# cannot unpack non-iterable NoneType object
# Frame took 0.07001495361328125 seconds
# 'NoneType' object is not iterable
# cannot unpack non-iterable NoneType object
# Frame took 0.08101820945739746 seconds
# 'NoneType' object is not iterable
# cannot unpack non-iterable NoneType object
# Frame took 0.08202505111694336 seconds
# 'NoneType' object is not iterable
# cannot unpack non-iterable NoneType object
# Frame took 0.08601927757263184 seconds
# 'NoneType' object is not iterable
# cannot unpack non-iterable NoneType object
# Frame took 0.08201169967651367 seconds
# 'NoneType' object is not iterable
# cannot unpack non-iterable NoneType object
# Frame took 0.06800699234008789 seconds
# 'NoneType' object is not iterable
# cannot unpack non-iterable NoneType object
# Frame took 0.08502840995788574 seconds
# 'NoneType' object is not iterable
# cannot unpack non-iterable NoneType object
# Frame took 0.07900834083557129 seconds
# 'NoneType' object is not iterable
# cannot unpack non-iterable NoneType object
# Frame took 0.08201789855957031 seconds
# 'NoneType' object is not iterable
# cannot unpack non-iterable NoneType object
# Frame took 0.05101156234741211 seconds
# 'NoneType' object is not iterable
# cannot unpack non-iterable NoneType object
# Frame took 0.05199718475341797 seconds
# 'NoneType' object is not iterable
# cannot unpack non-iterable NoneType object
# Frame took 0.05301260948181152 seconds
# 'NoneType' object is not iterable
# cannot unpack non-iterable NoneType object
# Frame took 0.04500865936279297 seconds
# 'NoneType' object is not iterable
# cannot unpack non-iterable NoneType object
# Frame took 0.04901313781738281 seconds
# 'NoneType' object is not iterable
# cannot unpack non-iterable NoneType object
# Frame took 0.0500178337097168 seconds
# 'NoneType' object is not iterable
# cannot unpack non-iterable NoneType object
# Frame took 0.05000591278076172 seconds
# 'NoneType' object is not iterable
# cannot unpack non-iterable NoneType object
# Frame took 0.05201125144958496 seconds
# 'NoneType' object is not iterable
# cannot unpack non-iterable NoneType object
# Frame took 0.0480046272277832 seconds
# 'NoneType' object is not iterable
# cannot unpack non-iterable NoneType object
# Frame took 0.058012962341308594 seconds
# 'NoneType' object is not iterable
# cannot unpack non-iterable NoneType object
# Frame took 0.04200911521911621 seconds
# 'NoneType' object is not iterable
# cannot unpack non-iterable NoneType object
# Frame took 0.05101799964904785 seconds
# 'NoneType' object is not iterable
# cannot unpack non-iterable NoneType object
# Frame took 0.05200529098510742 seconds
# 'NoneType' object is not iterable
# cannot unpack non-iterable NoneType object
# Frame took 0.04701685905456543 seconds
# 'NoneType' object is not iterable
# cannot unpack non-iterable NoneType object
# Frame took 0.05099797248840332 seconds
# 'NoneType' object is not iterable
# cannot unpack non-iterable NoneType object
# Frame took 0.0470120906829834 seconds
# 'NoneType' object is not iterable
# cannot unpack non-iterable NoneType object
